# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train=pd.read_csv('train.csv')

# %%
df_train.head()
# Out:
#    id  spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 0   1          33                   80.0           0.6250           0.3750
# 1   2         194                   80.0           0.6250           0.3750
# 2   3         227                   40.0           0.8125           0.1875
# 3   4         167                   30.0           0.7500           0.0000
# 4   5         194                   80.0           0.0000           0.6250
#
#    percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 0            0.000                9.9523                8.5513
# 1            0.000                6.1840                6.1838
# 2            0.000                9.7510                5.6595
# 3            0.250                5.0036                5.0034
# 4            0.375                6.6614                6.6612
#
#    lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 0                9.1775                     90.0026
# ...

# %%
sns.distplot(df_train['formation_energy_ev_natom'])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df_train['bandgap_energy_ev'])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(x=df_train['spacegroup'])

# %%
sns.countplot(x=df_train['number_of_total_atoms'])

# %%
sns.kdeplot(df_train['percent_atom_al'])
sns.kdeplot(df_train['percent_atom_ga'])
sns.kdeplot(df_train['percent_atom_in'])

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df_train['lattice_angle_alpha_degree'])
plt.tight_layout()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df_train['lattice_angle_beta_degree'])

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df_train['lattice_angle_gamma_degree'])

# %%
cor=df_train.corr()

# %%
plt.figure(figsize=(8,5))

sns.heatmap(cor,cmap='PiYG')

# %%
df_train.columns
# Out:
# Index(['id', 'spacegroup', 'number_of_total_atoms', 'percent_atom_al',
#        'percent_atom_ga', 'percent_atom_in', 'lattice_vector_1_ang',
#        'lattice_vector_2_ang', 'lattice_vector_3_ang',
#        'lattice_angle_alpha_degree', 'lattice_angle_beta_degree',
#        'lattice_angle_gamma_degree', 'formation_energy_ev_natom',
#        'bandgap_energy_ev'],
#       dtype='object')

# %%
pair_select=df_train[['number_of_total_atoms','percent_atom_al','percent_atom_in','lattice_vector_1_ang','lattice_angle_alpha_degree',
                      'formation_energy_ev_natom','bandgap_energy_ev']]

# %%
sns.pairplot(pair_select)

# %%
sns.boxplot(x='number_of_total_atoms',y='bandgap_energy_ev',data=df_train)

# %%
sns.boxplot(x='spacegroup',y='bandgap_energy_ev',data=df_train)

# %%
sns.boxplot(x='number_of_total_atoms',y='formation_energy_ev_natom',data=df_train)

# %%
sns.boxplot(x='spacegroup',y='formation_energy_ev_natom',data=df_train)

# %%
sns.jointplot(x='percent_atom_al',y='bandgap_energy_ev',data=df_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='percent_atom_ga',y='bandgap_energy_ev',data=df_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='percent_atom_in',y='bandgap_energy_ev',data=df_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='bandgap_energy_ev',y='lattice_vector_1_ang',data=df_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='bandgap_energy_ev',y='lattice_vector_2_ang',data=df_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='bandgap_energy_ev',y='lattice_vector_3_ang',data=df_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_train.isna().sum()
# Out:
# id                            0
# spacegroup                    0
# number_of_total_atoms         0
# percent_atom_al               0
# percent_atom_ga               0
# percent_atom_in               0
# lattice_vector_1_ang          0
# lattice_vector_2_ang          0
# lattice_vector_3_ang          0
# lattice_angle_alpha_degree    0
# lattice_angle_beta_degree     0
# lattice_angle_gamma_degree    0
# formation_energy_ev_natom     0
# bandgap_energy_ev             0
# dtype: int64

# %%
from sklearn.manifold import TSNE

print(df_train.shape)
# tsne = TSNE(2, verbose=1).fit_transform(df_train.values)
# plt.scatter(tsne[:, 0], tsne[:, 1])
# Out:
# (2400, 14)

# %%
# before anything else, create a decent baseline model

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.linear_model import MultiTaskElasticNetCV

X_train = df_train.iloc[:, 1:-2]
y_train = df_train.iloc[:, -2:]

model = 0 and GridSearchCV(
    SVR(),
    param_grid=[{
        'kernel': ['poly'],
        'degree': [2, 3],
        },
        {'kernel': ['rbf', 'linear']
        }],
    scoring='r2',
    verbose=1,
    n_jobs=4,
)
# model.fit(X_train, y_train.iloc[:, 0].values)
# print(model.best_estimator_)
# print(model.best_score_)
model = MultiTaskElasticNetCV(l1_ratio=np.logspace(-2, 0, num=10), n_alphas=15)
model.fit(X_train, y_train)
print(model.alpha_)
print(model.l1_ratio_)
print(model.score(X_train, y_train))

for ix in [0, 1]:
    model = ElasticNetCV(l1_ratio=np.logspace(-2, 0, num=10), n_alphas=15)
    model.fit(X_train, y_train.iloc[:, ix])
    
    print(f"\nFitting index {ix} separately")
    print(model.alpha_)
    print(model.score(X_train, y_train.iloc[:, ix]))
# Out:
# 0.0068301597951365076
# 1.0
# 0.7960265795198133
#
# Fitting index 0 separately
# 0.0028642955036458344
# 0.373987825866291
#
# Fitting index 1 separately
# 0.00620055595046875
# 0.8005215586556034

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor.feature_importances_
from sklearn.ensemble import RandomForestRegressor
import copy

model1 = GridSearchCV(
    RandomForestRegressor(),
    param_grid={'max_depth':[5,6,7,8],'max_features':[.3,.4,.5,.7,1.], 'n_estimators':[50,100,150]},
    scoring='r2',
    verbose=1,
    n_jobs=4,
)
model2 = copy.deepcopy(model1)

# %%
model1.fit(X_train, y_train.iloc[:,0])

# %%
print(model1.best_score_ ,model1.best_params_)
from pprint import pprint
pprint(sorted(zip(X_train.columns, model1.best_estimator_.feature_importances_), key=lambda x: -x[1]))
# Out:
# 0.8372993180973322 {'max_depth': 8, 'max_features': 1.0, 'n_estimators': 150}
# [('lattice_vector_3_ang', 0.40243654520394523),
#  ('percent_atom_in', 0.21010453564536216),
#  ('percent_atom_al', 0.12846998020514144),
#  ('lattice_vector_2_ang', 0.08224914908350422),
#  ('percent_atom_ga', 0.0675647209321471),
#  ('lattice_vector_1_ang', 0.030341713358611355),
#  ('spacegroup', 0.025596068306944428),
#  ('lattice_angle_beta_degree', 0.021613651270726435),
#  ('lattice_angle_alpha_degree', 0.0187313499697146),
#  ('lattice_angle_gamma_degree', 0.010118510121622895),
#  ('number_of_total_atoms', 0.0027737759022801174)]

# %%
model2.fit(X_train, y_train.iloc[:,1])
print(model2.best_score_ ,model2.best_params_)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=4)]: Done 180 out of 180 | elapsed:   24.3s finished
# 0.9464500161208735 {'max_depth': 8, 'max_features': 0.3, 'n_estimators': 100}

# %%
pprint(sorted(zip(X_train.columns, model2.best_estimator_.feature_importances_), key=lambda x: -x[1]))
# Out:
# [('percent_atom_in', 0.31581964601421453),
#  ('percent_atom_al', 0.20742477471649934),
#  ('lattice_vector_3_ang', 0.11405025636718437),
#  ('lattice_vector_1_ang', 0.08785768094509289),
#  ('lattice_vector_2_ang', 0.08535187283207475),
#  ('lattice_angle_alpha_degree', 0.05968574146478255),
#  ('lattice_angle_beta_degree', 0.043242627232656074),
#  ('percent_atom_ga', 0.026794020117397333),
#  ('lattice_angle_gamma_degree', 0.02570481815177122),
#  ('spacegroup', 0.02395940551878287),
#  ('number_of_total_atoms', 0.010109156639544164)]

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html
#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
from sklearn.ensemble import GradientBoostingRegressor
import copy

model1 = GridSearchCV(
    GradientBoostingRegressor(),
    param_grid={'loss':['ls','lad','huber','quantile'],'n_estimators':[200,300,700],'subsample':[.4,.5,.7,1.]},
    scoring='r2',
    verbose=1,
    n_jobs=4,
)
model2 = copy.deepcopy(model1)

# %%
model1.fit(X_train, y_train.iloc[:,0])
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=4)]: Done 144 out of 144 | elapsed:   47.8s finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'loss': ['ls', 'lad', 'huber', 'quantile'], 'n_estimators': [200, 300, 700], 'subsample': [0.4, 0.5, 0.7, 1.0]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
# ...

# %%
print(model1.best_score_ ,model1.best_params_)
from pprint import pprint
pprint(sorted(zip(X_train.columns, model1.best_estimator_.feature_importances_), key=lambda x: -x[1]))
# Out:
# 0.8462907397014889 {'loss': 'lad', 'n_estimators': 300, 'subsample': 0.7}
# [('lattice_vector_2_ang', 0.1780506437991504),
#  ('lattice_vector_1_ang', 0.12929543878452096),
#  ('lattice_vector_3_ang', 0.12431355510741296),
#  ('lattice_angle_beta_degree', 0.11205404790016284),
#  ('lattice_angle_alpha_degree', 0.10615748882387821),
#  ('percent_atom_in', 0.0871868021192277),
#  ('percent_atom_al', 0.08511663449376915),
#  ('percent_atom_ga', 0.07779462893485678),
#  ('lattice_angle_gamma_degree', 0.07540051883191402),
#  ('spacegroup', 0.021080535712922968),
#  ('number_of_total_atoms', 0.0035497054921842207)]

# %%
model2.fit(X_train, y_train.iloc[:,1])
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=4)]: Done 144 out of 144 | elapsed:   53.6s finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'loss': ['ls', 'lad', 'huber', 'quantile'], 'n_estimators': [200, 300, 700], 'subsample': [0.4, 0.5, 0.7, 1.0]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
# ...

# %%
print(model2.best_score_ ,model2.best_params_)
pprint(sorted(zip(X_train.columns, model2.best_estimator_.feature_importances_), key=lambda x: -x[1]))
# Out:
# 0.9509475285969279 {'loss': 'lad', 'n_estimators': 700, 'subsample': 0.4}
# [('lattice_vector_1_ang', 0.13678949430976148),
#  ('lattice_vector_3_ang', 0.12828540354681228),
#  ('lattice_vector_2_ang', 0.12424118094879279),
#  ('lattice_angle_alpha_degree', 0.11799260023951821),
#  ('lattice_angle_beta_degree', 0.11468548455583473),
#  ('lattice_angle_gamma_degree', 0.10933249400225238),
#  ('percent_atom_in', 0.09164496906682303),
#  ('percent_atom_al', 0.0911645424325854),
#  ('percent_atom_ga', 0.06988273713244433),
#  ('spacegroup', 0.010836182401009873),
#  ('number_of_total_atoms', 0.005144911364165295)]

# %%
#DOING FIT ON BOTH OUTPUTS FORMATION ENERGY AND BANDGAP ENERGY. DOES IT WORK?
#WHY A LOT OF WARNINGS?
model1.fit(X_train, y_train.iloc[:,0:1])
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
print(model1.best_score_ ,model1.best_params_)
from pprint import pprint
pprint(sorted(zip(X_train.columns, model1.best_estimator_.feature_importances_), key=lambda x: -x[1]))
# Out:
# 0.8477773762654166 {'loss': 'lad', 'n_estimators': 200, 'subsample': 0.7}
# [('lattice_vector_2_ang', 0.18020890307582843),
#  ('lattice_vector_3_ang', 0.12928046370614116),
#  ('lattice_vector_1_ang', 0.11568808960832926),
#  ('percent_atom_in', 0.10104057245706015),
#  ('lattice_angle_alpha_degree', 0.0973364259089273),
#  ('lattice_angle_beta_degree', 0.09172574721625748),
#  ('percent_atom_ga', 0.0895452147256772),
#  ('percent_atom_al', 0.0891861775505962),
#  ('lattice_angle_gamma_degree', 0.08482591918090321),
#  ('spacegroup', 0.020770869647866785),
#  ('number_of_total_atoms', 0.00039161692241281216)]

# %%
#USED https://xgboost.readthedocs.io/en/latest/python/python_api.html
import xgboost as xgb

model1 = GridSearchCV(
    xgb.XGBRegressor(),
    param_grid={'max_depth':[1,2,3,4,5,6,7],'n_estimators':[50,100,200]},
    scoring='r2',
    verbose=1,
    n_jobs=4,
)
model2 = copy.deepcopy(model1)

# %%
model1.fit(X_train, y_train.iloc[:,0])
# Out:
# Fitting 3 folds for each of 21 candidates, totalling 63 fits
# [Parallel(n_jobs=4)]: Done  56 out of  63 | elapsed:    3.4s remaining:    0.4s
# [Parallel(n_jobs=4)]: Done  63 out of  63 | elapsed:    3.9s finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'max_depth': [1, 2, 3, 4, 5, 6, 7], 'n_estimators': [50, 100, 200]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='r2', verbose=1)

# %%
print(model1.best_score_ ,model1.best_params_)
from pprint import pprint
pprint(sorted(zip(X_train.columns, model1.best_estimator_.feature_importances_), key=lambda x: -x[1]))
# Out:
# 0.8430981633045966 {'max_depth': 4, 'n_estimators': 50}
# [('percent_atom_in', 0.15373352),
#  ('percent_atom_al', 0.14787701),
#  ('lattice_vector_2_ang', 0.121522695),
#  ('lattice_vector_1_ang', 0.1068814),
#  ('lattice_angle_beta_degree', 0.103953145),
#  ('lattice_vector_3_ang', 0.095168374),
#  ('percent_atom_ga', 0.08345535),
#  ('lattice_angle_alpha_degree', 0.08345535),
#  ('spacegroup', 0.058565155),
#  ('lattice_angle_gamma_degree', 0.033674963),
#  ('number_of_total_atoms', 0.011713031)]

# %%
model2.fit(X_train, y_train.iloc[:,1])
# Out:
# Fitting 3 folds for each of 21 candidates, totalling 63 fits
# [Parallel(n_jobs=4)]: Done  56 out of  63 | elapsed:    3.9s remaining:    0.5s
# [Parallel(n_jobs=4)]: Done  63 out of  63 | elapsed:    4.6s finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'max_depth': [1, 2, 3, 4, 5, 6, 7], 'n_estimators': [50, 100, 200]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='r2', verbose=1)

# %%
print(model2.best_score_ ,model2.best_params_)
from pprint import pprint
pprint(sorted(zip(X_train.columns, model1.best_estimator_.feature_importances_), key=lambda x: -x[1]))
# Out:
# 0.9487257814019976 {'max_depth': 4, 'n_estimators': 100}
# [('percent_atom_in', 0.15373352),
#  ('percent_atom_al', 0.14787701),
#  ('lattice_vector_2_ang', 0.121522695),
#  ('lattice_vector_1_ang', 0.1068814),
#  ('lattice_angle_beta_degree', 0.103953145),
#  ('lattice_vector_3_ang', 0.095168374),
#  ('percent_atom_ga', 0.08345535),
#  ('lattice_angle_alpha_degree', 0.08345535),
#  ('spacegroup', 0.058565155),
#  ('lattice_angle_gamma_degree', 0.033674963),
#  ('number_of_total_atoms', 0.011713031)]

# %%
#from sklearn.manifold import TSNE

#print(df_train.shape)
#tsne = TSNE(2, verbose=1).fit_transform(df_train.values)
#plt.scatter(tsne[:, 0], tsne[:, 1])

#from sklearn.cluster import AgglomerativeClustering

# %%
#LET'S DO TRAIN TEST SPLIT AND LOOK WHAT IS THE PREDICTION FOR XGBOOST AND WHAT ARE THE IMPORTNT FEATURES
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.3, random_state=101)

# %%
model1=xgb.XGBRegressor()
model1.fit(X_train, y_train.iloc[:,0])
print(model1)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
y_pred=model1.predict(X_test)
plt.scatter(y_test.iloc[:,0],y_pred)

# %%
sns.distplot((y_test.iloc[:,0]-y_pred),bins=50);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
from xgboost import plot_importance
plot_importance(model1)

# %%
model2=xgb.XGBRegressor()
model2.fit(X_train, y_train.iloc[:,1])
print(model2)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
y_pred=model2.predict(X_test)
plt.scatter(y_test.iloc[:,1],y_pred)

# %%
sns.distplot((y_test.iloc[:,1]-y_pred),bins=50);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plot_importance(model2)
